# %% [markdown]
# # Week 10 Class Meetup via Google Classroom
#
# - Battle: US Gov't vs AI Industries, Personal Profiles, Pricing Concerns
# - Humanoid: Helix Learns to Fold Laundry (https://figure.ai)
#
# Pivot to *PROMPT ENGINEERING*.. let's tackle a popular question in the class, "What is this course teaching? What skills? What jobs? etc."
#
# **ADVANCED ARTIFICIAL INTELLIGENCE**
# - ML: Linear Regression, Logistic, Bagging, Boot Strapping
# - Agents
# - NLP: Sentiment Analysis
# - GEN AI: Prompt Engineering

# %% [markdown]
# ## Example Prompt A
#
# “Solve the problem. First give a brief plan (max 3 bullets), then the final answer, then a 1‑line check. Keep the plan concise, not a full step‑by‑step.”
# An item costs $240 after a 20% discount. What was the original price? Use the brief plan → final answer → 1‑line check format.
#
# ---
#
#
# ## Example Prompt B
#
# Design a notification strategy for a marketplace app to increase buyer replies without spamming. Provide brief plan (3 levers max) → policy proposal (bulleted) → 1‑line success metric.
#
# ---
#
#
# ## Example Prompt C
#
# You have 12 coins, one of which is counterfeit and weighs less or more than the others. You can use a balance scale 3 times.
# Provide 3 different reasoning strategies to identify the counterfeit coin, explain differences, then choose the most consistent plan.
#
# ---
#
#
# ## Example Prompt D
#
# Write a Python function to check if a string is a palindrome (ignoring spaces & case).
# Give 3 different solutions: (1) String slicing, (2) re + reverse, (3) Two-pointer method.
# Compare correctness and efficiency, then choose best.
#
# ---
#
#
#
# ## Example Prompt E
#
# Solve the problem by thinking in a Tree of Thoughts format:
#
# List multiple possible next steps/ideas at each stage.
#
# Briefly evaluate each option’s pros/cons.
#
# Choose the best branch and continue until reaching a final answer.”
#
# ---
#
#
# ## Example Prompt F
#
# You’re launching a new food delivery app in a saturated market.
# Stage 1: Brainstorm 3 differentiation strategies (e.g., price, niche, UX).
# Stage 2: For each, list 2–3 execution tactics.
# Stage 3: Evaluate and pick the most promising full path.
#
# ---
#
# ## Example Prompt G
#
# Write a short mystery story.
# Stage 1: List 3 possible openings.
# Stage 2: For each, propose 2 plot twists.
# Stage 3: Evaluate which storyline offers the most suspense, then write it.
#
# ---
#
# ## Example Prompt H
#
# Design a feature to improve seller trust on a marketplace app using the Skeleton of Thoughts method.”
#
# Skeleton might include:
#
# Identify trust pain points.
#
# Decide key trust signals.
#
# Choose implementation method.
#
# Define success metrics.
#
# Plan for rollout.
#
# ---
#
# ## Example Prompt I
#
# Write a query to get customers with >5 orders in the last 30 days. First solve, then verify by explaining how the WHERE and GROUP BY ensure correctness.
#
# ---
#
# ## Example Prompt J
#
# Write a 100-word summary of the importance of data governance.”
#
# Step 1: Draft summary.
#
# Step 2: Critique → “Too general; no mention of compliance or trust.”
#
# Step 3: Refine with specifics like GDPR, CCPA, and stakeholder trust.
#
# ---
#
# ## Example Prompt K
#
# “Is Mount Everest the tallest mountain in the world?”
#
# “Mount Everest’s peak height is 8,848 m.” → ENTAILMENT (known fact).
#
# “No other mountain has a greater height above sea level.” → ENTAILMENT (known fact).
#
# “Therefore, Mount Everest is the tallest mountain in the world.” → ENTAILMENT.
#
# ---
#
# ## Example Prompt L
#
# You have a table with column status. Rows where status = 'completed' should be counted as finished orders. The query counts rows where status IN ('completed', 'shipped'). Is this correct?
# “Completed orders have status = 'completed'.” → ENTAILMENT.
#
# “Shipped orders may not be completed.” → NEUTRAL (not guaranteed).
#
# “Including shipped in count might overcount completed orders.” → ENTAILMENT.
#
# Conclusion: Query is incorrect.
#
# ---
#
# ## Algorithm of Thoughts
#
# Design a loyalty program for a coffee shop chain. Use Algorithm of Thoughts:
#
# Stage 1: BFS — list all possible benefit types (discounts, freebies, points, experiences).
#
# Stage 2: Expand each with 2–3 implementation options.
#
# Stage 3: Prune by feasibility and ROI
#
# ---
#
# ## Chain of Density
#
# (https://chatgpt.com/share/689e6f76-62b4-8012-bb0e-f2ce303618c4)
#
# Apply Chain of Density to: Our coffee subscription delivers fresh, single-origin beans to your door weekly, sourced from sustainable farms and roasted to order for peak flavor.
#
# ---
#
#
# Apply Chain of Density to:
# Q2 revenue rose 15% year-over-year to $3.2B, driven by strong demand in Asia-Pacific and a 12% increase in e-commerce sales; operating margin improved by 2 points.
#
# ---
#
# ## Chain of Dictionaries
#
# Design a referral program for a mobile payment app.”
#
# Dictionary:
#
# Referral program: a system rewarding users for inviting new users.
#
# Mobile payment app: software that lets users send/receive money via smartphones.
#
# Reward: an incentive (cash, credit, discount).
#
# Solution: Link definitions into a plan.
#
# ---
#
# In a non-compete agreement, what does ‘geographic scope’ mean?”
#
# Dictionary:
#
# Non-compete agreement: a contract restricting a person from working for competitors for a period.
#
# Geographic scope: the physical area where the restriction applies.
#
# Solution: Clarify enforceability and limits.
#
# ---
#
# ## Chain of Symbol
#
# A number is 5 more than twice another number. Their sum is 26. Find the numbers.”
#
# Step 1 — Symbols: Let
# 𝑥
# x = first number,
# 𝑦
# y = second number.
#
# 𝑥
# =
# 2
# 𝑦
# +
# 5
# x=2y+5
#
# 𝑥
# +
# 𝑦
# =
# 26
# x+y=26
#
# Step 2 — Solve: Sub substitution →
# 2
# 𝑦
# +
# 5
# +
# 𝑦
# =
# 26
# 2y+5+y=26 →
# 3
# 𝑦
# =
# 21
# 3y=21 →
# 𝑦
# =
# 7
# y=7,
# 𝑥
# =
# 19
# x=19.
#
# Step 3 — Translate back: First number = 19, second = 7.
#
# ---
#
# ## Chain of Knowledge: Relevant Facts
#
# Why did the Industrial Revolution start in Britain?
#
# Fact 1: Britain had abundant coal and iron.
#
# Fact 2: It had a strong banking/finance system to fund factories.
#
# Fact 3: It had colonial markets for goods.
#
# Fact 4: It had technological innovators like James Watt.
#
# Answer: Indexing reduces query time by avoiding full scans.
#
# ---
#
# Why is indexing important for database performance?
#
# Fact 1: Indexes allow faster search in large tables.
#
# Fact 2: They work like a book index pointing to page locations.
#
# Fact 3: Without indexes, databases scan every row (full table scan).
#
# Answer: Indexing reduces query time by avoiding full scans.
#
# ---
